# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
weburl = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(weburl,'lxml')

# %%
tableCan = soup.find('table',{'class':'wikitable sortable'})
headers="Postcode,Borough,Neighbourhood"
table2=""
for tr in tableCan.find_all('tr'):
    row1=""
    for tds in tr.find_all('td'):
        row1=row1+","+tds.text
    table2=table2+row1[1:]
file=open("toronto.csv","wb")
file.write(bytes(table2,encoding="ascii",errors="ignore"))
df = pd.read_csv('toronto.csv',header=None)
df.columns=["Postalcode","Borough","Neighbourhood"]
indexOut = df[ df['Borough'] =='Not assigned'].index
df.drop(indexOut , inplace=True)
df.loc[df['Neighbourhood'] =='Not assigned' , 'Neighbourhood'] = df['Borough']

# %%
joinmore = df.groupby(['Postalcode','Borough'], sort=False).agg( ', '.join)
dffinal=joinmore.reset_index()

# %%
# !wget -q -O 'Toronto_long_lat_data.csv'  http://cocl.us/Geospatial_data
dflonlat = pd.read_csv('Toronto_long_lat_data.csv')
dflonlat.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
dflonlat.columns=['Postalcode','Latitude','Longitude']

# %%
tordf = pd.merge(dffinal,
                 dflonlat[['Postalcode','Latitude', 'Longitude']],
                 on='Postalcode')

# %%
tordf
# Out:
#     Postalcode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
import random 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.8.28-0                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.9.11-py36_0              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_2             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
CLIENT_ID = '0XBJZDANGRODWH3O4IDGTS4PTIUQQAGDBS5QFK1WCMPZM2EW' # your Foursquare ID
CLIENT_SECRET = '5MRPGORJGTYDSOTJWTPRAAPKND51PES11AC5UJJ3YPLKMTOO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0XBJZDANGRODWH3O4IDGTS4PTIUQQAGDBS5QFK1WCMPZM2EW
# CLIENT_SECRET:5MRPGORJGTYDSOTJWTPRAAPKND51PES11AC5UJJ3YPLKMTOO

# %% [markdown]
# # I used Google Maps to find random place in Toronto.

# %%
latitude = 43.761665
longitude = -79.490929
print(latitude, longitude)
# Out:
# 43.761665 -79.490929

# %% [markdown]
# # It is time for Pizza! I decided to find pizza restaruants/places near this random place/house!

# %%
search_query = 'Pizza'
radius = 500

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0XBJZDANGRODWH3O4IDGTS4PTIUQQAGDBS5QFK1WCMPZM2EW&client_secret=5MRPGORJGTYDSOTJWTPRAAPKND51PES11AC5UJJ3YPLKMTOO&ll=43.761665,-79.490929&v=20180604&query=Pizza&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5db0aee5c53093002c7a47f5'},
#  'response': {'venues': [{'id': '4dd8607be4cd37c893c4497d',
#     'name': 'Pizza Nova',
#     'location': {'address': '3928 Keele St.',
#      'lat': 43.762761957796464,
#      'lng': -79.49120791067236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.762761957796464,
#        'lng': -79.49120791067236}],
#      'distance': 124,
#      'postalCode': 'M3J 1N8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3928 Keele St.', 'Toronto ON M3J 1N8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860197',
#     'hasPerk': False},
#    {'id': '57c565d1498e511ed9c27695',
#     'name': 'Pizza Pizza',
#     'location': {'address': '1300 FINCH AVENUE WEST',
#      'lat': 43.764740618423275,
#      'lng': -79.48978543281555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.764740618423275,
#        'lng': -79.48978543281555}],
#      'distance': 354,
#      'postalCode': 'M3J 3K2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1300 FINCH AVENUE WEST',
#       'Toronto ON M3J 3K2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860197',
#     'hasPerk': False},
#    {'id': '4c3b57175810a5935581ba3c',
#     'name': 'Ninos Pizza',
#     'location': {'lat': 43.7598997761613,
#      'lng': -79.48857176063626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7598997761613,
#        'lng': -79.48857176063626}],
#      'distance': 273,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860197',
#     'hasPerk': False},
#    {'id': '50ff1716e4b098a6a6203244',
#     'name': "Regino's Pizza",
#     'location': {'crossStreet': 'Keele and Finch',
#      'lat': 43.764344,
#      'lng': -79.490137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.764344,
#        'lng': -79.490137}],
#      'distance': 304,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Keele and Finch', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860197',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
#
#                          id        location.address location.cc location.city  \
# 0  4dd8607be4cd37c893c4497d          3928 Keele St.          CA       Toronto
# 1  57c565d1498e511ed9c27695  1300 FINCH AVENUE WEST          CA       Toronto
# 2  4c3b57175810a5935581ba3c                     NaN          CA           NaN
# 3  50ff1716e4b098a6a6203244                     NaN          CA           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                124
# 1           Canada                  NaN                354
# 2           Canada                  NaN                273
# 3           Canada      Keele and Finch                304
#
#                            location.formattedAddress  \
# 0       [3928 Keele St., Toronto ON M3J 1N8, Canada]
# 1  [1300 FINCH AVENUE WEST, Toronto ON M3J 3K2, C...
# 2                                           [Canada]
# 3                          [Keele and Finch, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.76276195779646...     43.762762
# 1  [{'label': 'display', 'lat': 43.76474061842327...     43.764741
# 2  [{'label': 'display', 'lat': 43.7598997761613,...     43.759900
# 3  [{'label': 'display', 'lat': 43.764344, 'lng':...     43.764344
#
#    location.lng location.postalCode location.state            name  \
# 0    -79.491208             M3J 1N8             ON      Pizza Nova
# 1    -79.489785             M3J 3K2             ON     Pizza Pizza
# 2    -79.488572                 NaN            NaN     Ninos Pizza
# 3    -79.490137                 NaN            NaN  Regino's Pizza
#
#      referralId
# 0  v-1571860197
# 1  v-1571860197
# 2  v-1571860197
# 3  v-1571860197

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#              name   categories                 address  cc     city country  \
# 0      Pizza Nova  Pizza Place          3928 Keele St.  CA  Toronto  Canada
# 1     Pizza Pizza  Pizza Place  1300 FINCH AVENUE WEST  CA  Toronto  Canada
# 2     Ninos Pizza  Pizza Place                     NaN  CA      NaN  Canada
# 3  Regino's Pizza  Pizza Place                     NaN  CA      NaN  Canada
#
#        crossStreet  distance  \
# 0              NaN       124
# 1              NaN       354
# 2              NaN       273
# 3  Keele and Finch       304
#
#                                     formattedAddress  \
# 0       [3928 Keele St., Toronto ON M3J 1N8, Canada]
# 1  [1300 FINCH AVENUE WEST, Toronto ON M3J 3K2, C...
# 2                                           [Canada]
# 3                          [Keele and Finch, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.76276195779646...  43.762762 -79.491208
# 1  [{'label': 'display', 'lat': 43.76474061842327...  43.764741 -79.489785
# 2  [{'label': 'display', 'lat': 43.7598997761613,...  43.759900 -79.488572
# 3  [{'label': 'display', 'lat': 43.764344, 'lng':...  43.764344 -79.490137
#
#   postalCode state                        id
# 0    M3J 1N8    ON  4dd8607be4cd37c893c4497d
# 1    M3J 3K2    ON  57c565d1498e511ed9c27695
# 2        NaN   NaN  4c3b57175810a5935581ba3c
# 3        NaN   NaN  50ff1716e4b098a6a6203244

# %%
dataframe_filtered.name
# Out:
# 0        Pizza Nova
# 1       Pizza Pizza
# 2       Ninos Pizza
# 3    Regino's Pizza
# Name: name, dtype: object

# %% [markdown]
# Let's see where are the pizza places ?

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='My random house',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Let's try to make radius bigger! There must be a lot of pizza restaurants around my random house in Toronto!

# %%
radius = 5000
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0XBJZDANGRODWH3O4IDGTS4PTIUQQAGDBS5QFK1WCMPZM2EW&client_secret=5MRPGORJGTYDSOTJWTPRAAPKND51PES11AC5UJJ3YPLKMTOO&ll=43.761665,-79.490929&v=20180604&query=Pizza&radius=5000&limit=30'

# %%
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5db0b1aac53093002c89c03a'},
#  'response': {'venues': [{'id': '4bc0eda24cdfc9b6a4ca9321',
#     'name': '341 Pizza & Wings',
#     'location': {'address': 'Four Winds',
#      'lat': 43.76346437768995,
#      'lng': -79.49847340621493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76346437768995,
#        'lng': -79.49847340621493}],
#      'distance': 638,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Four Winds', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4dd8607be4cd37c893c4497d',
#     'name': 'Pizza Nova',
#     'location': {'address': '3928 Keele St.',
#      'lat': 43.762761957796464,
#      'lng': -79.49120791067236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.762761957796464,
#        'lng': -79.49120791067236}],
#      'distance': 124,
#      'postalCode': 'M3J 1N8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3928 Keele St.', 'Toronto ON M3J 1N8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '57c565d1498e511ed9c27695',
#     'name': 'Pizza Pizza',
#     'location': {'address': '1300 FINCH AVENUE WEST',
#      'lat': 43.764740618423275,
#      'lng': -79.48978543281555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.764740618423275,
#        'lng': -79.48978543281555}],
#      'distance': 354,
#      'postalCode': 'M3J 3K2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1300 FINCH AVENUE WEST',
#       'Toronto ON M3J 3K2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4c3b57175810a5935581ba3c',
#     'name': 'Ninos Pizza',
#     'location': {'lat': 43.7598997761613,
#      'lng': -79.48857176063626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7598997761613,
#        'lng': -79.48857176063626}],
#      'distance': 273,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '50ff1716e4b098a6a6203244',
#     'name': "Regino's Pizza",
#     'location': {'crossStreet': 'Keele and Finch',
#      'lat': 43.764344,
#      'lng': -79.490137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.764344,
#        'lng': -79.490137}],
#      'distance': 304,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Keele and Finch', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4ae4d11bf964a5206f9e21e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '800 Unit C-01 Steeles Avenue West',
#      'lat': 43.79290649613756,
#      'lng': -79.44833993911742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.79290649613756,
#        'lng': -79.44833993911742}],
#      'distance': 4879,
#      'postalCode': 'L4J 7L2',
#      'cc': 'CA',
#      'city': 'Thornhill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['800 Unit C-01 Steeles Avenue West',
#       'Thornhill ON L4J 7L2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '51198b6be4b02eba04902109',
#     'name': 'Pizza Pizza',
#     'location': {'lat': 43.763324933560696,
#      'lng': -79.49985175333656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.763324933560696,
#        'lng': -79.49985175333656}],
#      'distance': 740,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '54ff654d498ee5e08c20b2c8',
#     'name': 'Student Pizza & Curry',
#     'location': {'lat': 43.76347505539495,
#      'lng': -79.49846242328593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76347505539495,
#        'lng': -79.49846242328593}],
#      'distance': 638,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '5c51eaa646e1b6002cb6eb3c',
#     'name': 'Sapore Pizza & Wing',
#     'location': {'address': '45 Four Winds Drive',
#      'crossStreet': 'Sentinel Road',
#      'lat': 43.763762,
#      'lng': -79.498303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.763762,
#        'lng': -79.498303}],
#      'distance': 637,
#      'postalCode': 'M3J 1K7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['45 Four Winds Drive (Sentinel Road)',
#       'Toronto ON M3J 1K7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4bc232f44cdfc9b638c09521',
#     'name': 'Pizza Nova',
#     'location': {'address': '2210 Jane Street',
#      'lat': 43.72306,
#      'lng': -79.509217,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72306,
#        'lng': -79.509217}],
#      'distance': 4542,
#      'postalCode': 'M3M 1A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2210 Jane Street', 'Toronto ON M3M 1A4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4b89a1daf964a520c34732e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '3358 Keele St.',
#      'lat': 43.74579054879979,
#      'lng': -79.48736151651204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.74579054879979,
#        'lng': -79.48736151651204}],
#      'distance': 1790,
#      'postalCode': 'M3J 1L5',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3358 Keele St.',
#       'North York ON M3J 1L5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4b69c896f964a520f7b32be3',
#     'name': 'Pizza Pizza',
#     'location': {'address': 'York University',
#      'crossStreet': 'Curtis Lecture Halls',
#      'lat': 43.77255490770365,
#      'lng': -79.50464560366575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77255490770365,
#        'lng': -79.50464560366575}],
#      'distance': 1638,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['York University (Curtis Lecture Halls)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '51198b4be4b05b4100726189',
#     'name': 'Pizza Pizza',
#     'location': {'lat': 43.77194380109299,
#      'lng': -79.5010214100999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77194380109299,
#        'lng': -79.5010214100999}],
#      'distance': 1402,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4ee91cd3e300cc66b42ceede',
#     'name': 'Pizza Hut',
#     'location': {'address': '1949 Finch Avenue W.',
#      'lat': 43.75633958118749,
#      'lng': -79.51781778764257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75633958118749,
#        'lng': -79.51781778764257}],
#      'distance': 2241,
#      'postalCode': 'M3N 2V3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1949 Finch Avenue W.',
#       'Toronto ON M3N 2V3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4d26693c467d6ea8e3d7b395',
#     'name': 'Pizza Nova',
#     'location': {'address': '520 Wilson Heights Blvd.',
#      'lat': 43.75085593685064,
#      'lng': -79.45639231008485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75085593685064,
#        'lng': -79.45639231008485}],
#      'distance': 3026,
#      'postalCode': 'M3H 2V6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['520 Wilson Heights Blvd.',
#       'Toronto ON M3H 2V6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4b6dcea4f964a520b3912ce3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '330 Wilson Ave.',
#      'lat': 43.73666919003047,
#      'lng': -79.44148338931069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73666919003047,
#        'lng': -79.44148338931069}],
#      'distance': 4853,
#      'postalCode': 'M3H 1S9',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['330 Wilson Ave.',
#       'North York ON M3H 1S9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4cb8723890c9a14328b57fd6',
#     'name': 'Pizza Nova',
#     'location': {'address': '1054 Centre Street',
#      'crossStreet': 'Bathurst',
#      'lat': 43.80927680557462,
#      'lng': -79.46036570181424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.80927680557462,
#        'lng': -79.46036570181424}],
#      'distance': 5841,
#      'postalCode': 'L4J 3M8',
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1054 Centre Street (Bathurst)',
#       'Vaughan ON L4J 3M8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4dc2f240e4cda23545602f2b',
#     'name': 'Express Pizza & Grill',
#     'location': {'address': '4917 Bathurst St.',
#      'crossStreet': 'at Finch Ave.',
#      'lat': 43.77330995743962,
#      'lng': -79.4423366429039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77330995743962,
#        'lng': -79.4423366429039}],
#      'distance': 4115,
#      'postalCode': 'M2R 1X8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4917 Bathurst St. (at Finch Ave.)',
#       'Toronto ON M2R 1X8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4be44e62910020a19484d114',
#     'name': "Domino's Pizza",
#     'location': {'address': '4207 Keele St',
#      'lat': 43.77344076002103,
#      'lng': -79.49280054786901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77344076002103,
#        'lng': -79.49280054786901}],
#      'distance': 1319,
#      'postalCode': 'M3J 3T8',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4207 Keele St', 'North York ON M3J 3T8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4ca539bfd971b1f7bf0ef5e0',
#     'name': 'Pizza Pizza',
#     'location': {'address': '1837 Finch Avenue West, Unit T-3',
#      'lat': 43.756185976894656,
#      'lng': -79.5154595375061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.756185976894656,
#        'lng': -79.5154595375061}],
#      'distance': 2064,
#      'postalCode': 'M3N 2H1',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1837 Finch Avenue West, Unit T-3',
#       'North York ON M3N 2H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4b8d56e9f964a5209ff532e3',
#     'name': 'Boston Pizza',
#     'location': {'address': '180 Rimrock Road',
#      'crossStreet': 'at W R. Allen Rd',
#      'lat': 43.758133739760524,
#      'lng': -79.46566021611487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.758133739760524,
#        'lng': -79.46566021611487}],
#      'distance': 2069,
#      'postalCode': 'M3J 3A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['180 Rimrock Road (at W R. Allen Rd)',
#       'Toronto ON M3J 3A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4e70bd86c65b340cde88a4e3',
#     'name': 'Panzerotto Pizza',
#     'location': {'address': 'York University (Student Centre)',
#      'lat': 43.773804435493815,
#      'lng': -79.50159250468073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.773804435493815,
#        'lng': -79.50159250468073}],
#      'distance': 1600,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['York University (Student Centre)', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4d77e9719ee9a35dbc0ebaf8',
#     'name': 'Pizza Bella',
#     'location': {'lat': 43.734007993326614,
#      'lng': -79.48338161848379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.734007993326614,
#        'lng': -79.48338161848379}],
#      'distance': 3137,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4bcb72b3cc8cd13a5c70bfcf',
#     'name': 'Pizza Pizza',
#     'location': {'address': '1080 Wilson Ave.',
#      'lat': 43.7281178372513,
#      'lng': -79.4805022638516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7281178372513,
#        'lng': -79.4805022638516}],
#      'distance': 3827,
#      'postalCode': 'M3K 1G6',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1080 Wilson Ave.',
#       'North York ON M3K 1G6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '5622b250498e220017e327a3',
#     'name': 'Pie Wood Fired Pizza Joint',
#     'location': {'address': '200 Whitmore Rd',
#      'crossStreet': 'Hwy 7',
#      'lat': 43.78651992879987,
#      'lng': -79.55719122002797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.78651992879987,
#        'lng': -79.55719122002797}],
#      'distance': 6001,
#      'cc': 'CA',
#      'city': 'Woodbridge',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Whitmore Rd (Hwy 7)',
#       'Woodbridge ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '5294c2f7498e30518336a782',
#     'name': "Gino's Pizza",
#     'location': {'address': '4700 Keele Street (Student Centre )',
#      'lat': 43.773799896240234,
#      'lng': -79.50218200683594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.773799896240234,
#        'lng': -79.50218200683594}],
#      'distance': 1625,
#      'cc': 'CA',
#      'city': 'Vaughan',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4700 Keele Street (Student Centre )',
#       'Vaughan ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4ec453d98b812a20648b7480',
#     'name': 'Pizza Nova',
#     'location': {'crossStreet': 'Dufferin & Steeles',
#      'lat': 43.786907,
#      'lng': -79.469002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.786907,
#        'lng': -79.469002}],
#      'distance': 3316,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Dufferin & Steeles', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '5d2a182eafbe290023fa1804',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '4710 Jane St',
#      'lat': 43.769269,
#      'lng': -79.521371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.769269,
#        'lng': -79.521371}],
#      'distance': 2589,
#      'postalCode': 'M3N 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4710 Jane St', 'Toronto ON M3N 2L2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4c45a6c4f799e21efa74afa2',
#     'name': 'Pizza Pizza',
#     'location': {'address': '2731 JANE STREET',
#      'lat': 43.74108518369447,
#      'lng': -79.51349681782587,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.74108518369447,
#        'lng': -79.51349681782587}],
#      'distance': 2922,
#      'postalCode': 'M3L 1S3',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2731 JANE STREET',
#       'North York ON M3L 1S3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False},
#    {'id': '4f651fefe4b041039e5be9a9',
#     'name': 'Pizza e Pazzi',
#     'location': {'lat': 43.74956700597397,
#      'lng': -79.45698149082254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.74956700597397,
#        'lng': -79.45698149082254}],
#      'distance': 3043,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571860906',
#     'hasPerk': False}]}}

# %%
venues2 = results2['response']['venues']
dataframe2 = json_normalize(venues2)
dataframe2.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
#
#                          id        location.address location.cc location.city  \
# 0  4bc0eda24cdfc9b6a4ca9321              Four Winds          CA       Toronto
# 1  4dd8607be4cd37c893c4497d          3928 Keele St.          CA       Toronto
# 2  57c565d1498e511ed9c27695  1300 FINCH AVENUE WEST          CA       Toronto
# 3  4c3b57175810a5935581ba3c                     NaN          CA           NaN
# 4  50ff1716e4b098a6a6203244                     NaN          CA           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                638
# 1           Canada                  NaN                124
# 2           Canada                  NaN                354
# 3           Canada                  NaN                273
# 4           Canada      Keele and Finch                304
#
#                            location.formattedAddress  \
# 0                   [Four Winds, Toronto ON, Canada]
# 1       [3928 Keele St., Toronto ON M3J 1N8, Canada]
# 2  [1300 FINCH AVENUE WEST, Toronto ON M3J 3K2, C...
# 3                                           [Canada]
# 4                          [Keele and Finch, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.76346437768995...     43.763464
# 1  [{'label': 'display', 'lat': 43.76276195779646...     43.762762
# 2  [{'label': 'display', 'lat': 43.76474061842327...     43.764741
# 3  [{'label': 'display', 'lat': 43.7598997761613,...     43.759900
# 4  [{'label': 'display', 'lat': 43.764344, 'lng':...     43.764344
#
#    location.lng location.postalCode location.state               name  \
# 0    -79.498473                 NaN             ON  341 Pizza & Wings
# 1    -79.491208             M3J 1N8             ON         Pizza Nova
# 2    -79.489785             M3J 3K2             ON        Pizza Pizza
# 3    -79.488572                 NaN            NaN        Ninos Pizza
# 4    -79.490137                 NaN            NaN     Regino's Pizza
#
#      referralId
# 0  v-1571860906
# 1  v-1571860906
# 2  v-1571860906
# 3  v-1571860906
# 4  v-1571860906

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe2.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                           name           categories  \
# 0            341 Pizza & Wings          Pizza Place
# 1                   Pizza Nova          Pizza Place
# 2                  Pizza Pizza          Pizza Place
# 3                  Ninos Pizza          Pizza Place
# 4               Regino's Pizza          Pizza Place
# 5                  Pizza Pizza          Pizza Place
# 6                  Pizza Pizza          Pizza Place
# 7        Student Pizza & Curry          Pizza Place
# 8          Sapore Pizza & Wing          Pizza Place
# 9                   Pizza Nova          Pizza Place
# 10                 Pizza Pizza          Pizza Place
# 11                 Pizza Pizza          Pizza Place
# 12                 Pizza Pizza          Pizza Place
# 13                   Pizza Hut          Pizza Place
# 14                  Pizza Nova          Pizza Place
# 15                 Pizza Pizza          Pizza Place
# 16                  Pizza Nova  American Restaurant
# 17       Express Pizza & Grill          Pizza Place
# 18              Domino's Pizza          Pizza Place
# 19                 Pizza Pizza          Pizza Place
# 20                Boston Pizza          Pizza Place
# 21            Panzerotto Pizza          Pizza Place
# 22                 Pizza Bella          Pizza Place
# 23                 Pizza Pizza          Pizza Place
# 24  Pie Wood Fired Pizza Joint          Pizza Place
# 25                Gino's Pizza          Pizza Place
# 26                  Pizza Nova          Pizza Place
# 27        Little Caesars Pizza          Pizza Place
# 28                 Pizza Pizza          Pizza Place
# 29               Pizza e Pazzi   Italian Restaurant
#
#                                 address  cc        city country  \
# 0                            Four Winds  CA     Toronto  Canada
# 1                        3928 Keele St.  CA     Toronto  Canada
# 2                1300 FINCH AVENUE WEST  CA     Toronto  Canada
# 3                                   NaN  CA         NaN  Canada
# 4                                   NaN  CA         NaN  Canada
# 5     800 Unit C-01 Steeles Avenue West  CA   Thornhill  Canada
# 6                                   NaN  CA         NaN  Canada
# 7                                   NaN  CA         NaN  Canada
# 8                   45 Four Winds Drive  CA     Toronto  Canada
# 9                      2210 Jane Street  CA     Toronto  Canada
# 10                       3358 Keele St.  CA  North York  Canada
# 11                      York University  CA     Toronto  Canada
# 12                                  NaN  CA         NaN  Canada
# 13                 1949 Finch Avenue W.  CA     Toronto  Canada
# 14             520 Wilson Heights Blvd.  CA     Toronto  Canada
# 15                      330 Wilson Ave.  CA  North York  Canada
# 16                   1054 Centre Street  CA     Vaughan  Canada
# 17                    4917 Bathurst St.  CA     Toronto  Canada
# 18                        4207 Keele St  CA  North York  Canada
# 19     1837 Finch Avenue West, Unit T-3  CA  North York  Canada
# 20                     180 Rimrock Road  CA     Toronto  Canada
# 21     York University (Student Centre)  CA         NaN  Canada
# 22                                  NaN  CA     Toronto  Canada
# 23                     1080 Wilson Ave.  CA  North York  Canada
# 24                      200 Whitmore Rd  CA  Woodbridge  Canada
# 25  4700 Keele Street (Student Centre )  CA     Vaughan  Canada
# 26                                  NaN  CA     Toronto  Canada
# 27                         4710 Jane St  CA     Toronto  Canada
# 28                     2731 JANE STREET  CA  North York  Canada
# 29                                  NaN  CA         NaN  Canada
#
#              crossStreet  distance  \
# 0                    NaN       638
# 1                    NaN       124
# 2                    NaN       354
# 3                    NaN       273
# 4        Keele and Finch       304
# 5                    NaN      4879
# 6                    NaN       740
# 7                    NaN       638
# 8          Sentinel Road       637
# 9                    NaN      4542
# 10                   NaN      1790
# 11  Curtis Lecture Halls      1638
# 12                   NaN      1402
# 13                   NaN      2241
# 14                   NaN      3026
# 15                   NaN      4853
# 16              Bathurst      5841
# 17         at Finch Ave.      4115
# 18                   NaN      1319
# 19                   NaN      2064
# 20      at W R. Allen Rd      2069
# 21                   NaN      1600
# 22                   NaN      3137
# 23                   NaN      3827
# 24                 Hwy 7      6001
# 25                   NaN      1625
# 26    Dufferin & Steeles      3316
# 27                   NaN      2589
# 28                   NaN      2922
# 29                   NaN      3043
#
#                                      formattedAddress  \
# 0                    [Four Winds, Toronto ON, Canada]
# 1        [3928 Keele St., Toronto ON M3J 1N8, Canada]
# 2   [1300 FINCH AVENUE WEST, Toronto ON M3J 3K2, C...
# 3                                            [Canada]
# 4                           [Keele and Finch, Canada]
# 5   [800 Unit C-01 Steeles Avenue West, Thornhill ...
# 6                                            [Canada]
# 7                                            [Canada]
# 8   [45 Four Winds Drive (Sentinel Road), Toronto ...
# 9      [2210 Jane Street, Toronto ON M3M 1A4, Canada]
# 10    [3358 Keele St., North York ON M3J 1L5, Canada]
# 11  [York University (Curtis Lecture Halls), Toron...
# 12                                           [Canada]
# 13  [1949 Finch Avenue W., Toronto ON M3N 2V3, Can...
# 14  [520 Wilson Heights Blvd., Toronto ON M3H 2V6,...
# 15   [330 Wilson Ave., North York ON M3H 1S9, Canada]
# 16  [1054 Centre Street (Bathurst), Vaughan ON L4J...
# 17  [4917 Bathurst St. (at Finch Ave.), Toronto ON...
# 18     [4207 Keele St, North York ON M3J 3T8, Canada]
# 19  [1837 Finch Avenue West, Unit T-3, North York ...
# 20  [180 Rimrock Road (at W R. Allen Rd), Toronto ...
# 21         [York University (Student Centre), Canada]
# 22                               [Toronto ON, Canada]
# 23  [1080 Wilson Ave., North York ON M3K 1G6, Canada]
# 24   [200 Whitmore Rd (Hwy 7), Woodbridge ON, Canada]
# 25  [4700 Keele Street (Student Centre ), Vaughan ...
# 26           [Dufferin & Steeles, Toronto ON, Canada]
# 27         [4710 Jane St, Toronto ON M3N 2L2, Canada]
# 28  [2731 JANE STREET, North York ON M3L 1S3, Canada]
# 29                                           [Canada]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.76346437768995...  43.763464 -79.498473
# 1   [{'label': 'display', 'lat': 43.76276195779646...  43.762762 -79.491208
# 2   [{'label': 'display', 'lat': 43.76474061842327...  43.764741 -79.489785
# 3   [{'label': 'display', 'lat': 43.7598997761613,...  43.759900 -79.488572
# 4   [{'label': 'display', 'lat': 43.764344, 'lng':...  43.764344 -79.490137
# 5   [{'label': 'display', 'lat': 43.79290649613756...  43.792906 -79.448340
# 6   [{'label': 'display', 'lat': 43.76332493356069...  43.763325 -79.499852
# 7   [{'label': 'display', 'lat': 43.76347505539495...  43.763475 -79.498462
# 8   [{'label': 'display', 'lat': 43.763762, 'lng':...  43.763762 -79.498303
# 9   [{'label': 'display', 'lat': 43.72306, 'lng': ...  43.723060 -79.509217
# 10  [{'label': 'display', 'lat': 43.74579054879979...  43.745791 -79.487362
# 11  [{'label': 'display', 'lat': 43.77255490770365...  43.772555 -79.504646
# 12  [{'label': 'display', 'lat': 43.77194380109299...  43.771944 -79.501021
# 13  [{'label': 'display', 'lat': 43.75633958118749...  43.756340 -79.517818
# 14  [{'label': 'display', 'lat': 43.75085593685064...  43.750856 -79.456392
# 15  [{'label': 'display', 'lat': 43.73666919003047...  43.736669 -79.441483
# 16  [{'label': 'display', 'lat': 43.80927680557462...  43.809277 -79.460366
# 17  [{'label': 'display', 'lat': 43.77330995743962...  43.773310 -79.442337
# 18  [{'label': 'display', 'lat': 43.77344076002103...  43.773441 -79.492801
# 19  [{'label': 'display', 'lat': 43.75618597689465...  43.756186 -79.515460
# 20  [{'label': 'display', 'lat': 43.75813373976052...  43.758134 -79.465660
# 21  [{'label': 'display', 'lat': 43.77380443549381...  43.773804 -79.501593
# 22  [{'label': 'display', 'lat': 43.73400799332661...  43.734008 -79.483382
# 23  [{'label': 'display', 'lat': 43.7281178372513,...  43.728118 -79.480502
# 24  [{'label': 'display', 'lat': 43.78651992879987...  43.786520 -79.557191
# 25  [{'label': 'display', 'lat': 43.77379989624023...  43.773800 -79.502182
# 26  [{'label': 'display', 'lat': 43.786907, 'lng':...  43.786907 -79.469002
# 27  [{'label': 'display', 'lat': 43.769269, 'lng':...  43.769269 -79.521371
# 28  [{'label': 'display', 'lat': 43.74108518369447...  43.741085 -79.513497
# 29  [{'label': 'display', 'lat': 43.74956700597397...  43.749567 -79.456981
#
#    postalCode state                        id
# 0         NaN    ON  4bc0eda24cdfc9b6a4ca9321
# 1     M3J 1N8    ON  4dd8607be4cd37c893c4497d
# 2     M3J 3K2    ON  57c565d1498e511ed9c27695
# 3         NaN   NaN  4c3b57175810a5935581ba3c
# 4         NaN   NaN  50ff1716e4b098a6a6203244
# 5     L4J 7L2    ON  4ae4d11bf964a5206f9e21e3
# 6         NaN   NaN  51198b6be4b02eba04902109
# 7         NaN   NaN  54ff654d498ee5e08c20b2c8
# 8     M3J 1K7    ON  5c51eaa646e1b6002cb6eb3c
# 9     M3M 1A4    ON  4bc232f44cdfc9b638c09521
# 10    M3J 1L5    ON  4b89a1daf964a520c34732e3
# 11        NaN    ON  4b69c896f964a520f7b32be3
# 12        NaN   NaN  51198b4be4b05b4100726189
# 13    M3N 2V3    ON  4ee91cd3e300cc66b42ceede
# 14    M3H 2V6    ON  4d26693c467d6ea8e3d7b395
# 15    M3H 1S9    ON  4b6dcea4f964a520b3912ce3
# 16    L4J 3M8    ON  4cb8723890c9a14328b57fd6
# 17    M2R 1X8    ON  4dc2f240e4cda23545602f2b
# 18    M3J 3T8    ON  4be44e62910020a19484d114
# 19    M3N 2H1    ON  4ca539bfd971b1f7bf0ef5e0
# 20    M3J 3A6    ON  4b8d56e9f964a5209ff532e3
# 21        NaN   NaN  4e70bd86c65b340cde88a4e3
# 22        NaN    ON  4d77e9719ee9a35dbc0ebaf8
# 23    M3K 1G6    ON  4bcb72b3cc8cd13a5c70bfcf
# 24        NaN    ON  5622b250498e220017e327a3
# 25        NaN    ON  5294c2f7498e30518336a782
# 26        NaN    ON  4ec453d98b812a20648b7480
# 27    M3N 2L2    ON  5d2a182eafbe290023fa1804
# 28    M3L 1S3    ON  4c45a6c4f799e21efa74afa2
# 29        NaN   NaN  4f651fefe4b041039e5be9a9

# %%
dataframe_filtered.name
# Out:
# 0              341 Pizza & Wings
# 1                     Pizza Nova
# 2                    Pizza Pizza
# 3                    Ninos Pizza
# 4                 Regino's Pizza
# 5                    Pizza Pizza
# 6                    Pizza Pizza
# 7          Student Pizza & Curry
# 8            Sapore Pizza & Wing
# 9                     Pizza Nova
# 10                   Pizza Pizza
# 11                   Pizza Pizza
# 12                   Pizza Pizza
# 13                     Pizza Hut
# 14                    Pizza Nova
# 15                   Pizza Pizza
# 16                    Pizza Nova
# 17         Express Pizza & Grill
# 18                Domino's Pizza
# 19                   Pizza Pizza
# 20                  Boston Pizza
# 21              Panzerotto Pizza
# 22                   Pizza Bella
# 23                   Pizza Pizza
# 24    Pie Wood Fired Pizza Joint
# 25                  Gino's Pizza
# 26                    Pizza Nova
# 27          Little Caesars Pizza
# 28                   Pizza Pizza
# 29                 Pizza e Pazzi
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='My random house',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
